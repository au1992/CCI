# %% [markdown]
# ### Import dependences: OpenCV, skimage, numpy, imutils ( Core function is based on opencv and skimage)

# %%
import time
import os 
import cv2
import numpy as np
from imutils import paths
from skimage import util
from skimage.segmentation import clear_border
from skimage.measure import label, regionprops

print("ok")
# Out:
# ok

# %%
def ComputeMask(img):
    if np.mean(img)>70:
        img=util.invert(img)
        
    # convert to black and white
    ret,mask= cv2.threshold(img,0,1,cv2.THRESH_BINARY+cv2.THRESH_OTSU)
    
    # Range filter
    kernel = np.ones((15,15),np.uint8)
    dil=cv2.dilate(img,kernel,iterations = 1)
    ero=cv2.erode(mask,kernel,iterations = 1)
    mask=dil-ero
    ret,mask= cv2.threshold(mask,0,1,cv2.THRESH_BINARY+cv2.THRESH_OTSU)
    
    # dilate with horizontal and vertical lines of different size
    for i in range(20,30):
        kernel = np.ones((i,5),np.uint8)
        mask = cv2.dilate(mask,kernel,iterations = 1)    
        
        kernel = np.ones((5,i),np.uint8)
        mask = cv2.dilate(mask,kernel,iterations = 1)
        
        ret,mask= cv2.threshold(mask,0,1,cv2.THRESH_BINARY+cv2.THRESH_OTSU)
        
        kernel = np.ones((7,7),np.uint8)
        mask=cv2.erode(mask,kernel,iterations = 2)
        
        
    # invert the mask
    mask=(1-mask)
    
    # Cleaning of the mask
    if np.count_nonzero(clear_border(mask))>0:
        mask = clear_border(mask)
    else:
        s1,s2=mask.shape
        border=mask*0
        border[0:20,:]=mask[0:20,:]
        border[s1-20:s1,:]=mask[s1-20:s1,:]
        border[:,0:20]=mask[:,0:20]
        border[:,s2-20:s2]=mask[:,s2-20:s2]
        mask=mask-border
        
    kernel = np.ones((5,5),np.uint8)
    mask=cv2.erode(mask,kernel,iterations = 10)
    ret,mask= cv2.threshold(mask,0,1,cv2.THRESH_BINARY+cv2.THRESH_OTSU)
    return mask


# from the mask compute the bounding box for the mask
def ComputeBoxDim(mask):
    label_image = label(mask)
    max_area=0
    for region in regionprops(label_image):
        if region.area >= max_area:
            minr, minc, maxr, maxc = region.bbox
            max_area=region.area
    return minr, minc, maxr, maxc

# from the bounding box coordinates crop the image of a fixed size (600,1000).
def CropImage(img,minr, minc, maxr, maxc):
    CropImg = img[minr:maxr,  minc:maxc]
    s1,s2=CropImg.shape
    if s1>600 and s2>1000:
        s1=np.uint16(s1/2)
        s2=np.uint16(s2/2)
        CropImg = CropImg[s1-300:s1+300,  s2-500:s2+500]
    return CropImg


def AutomaticBoxCrop(ImageList,DestPath):
    # load all the images in the ImageList
    # ImageList = list(paths.list_images(InputPath))
   

    # Create the destination folder if is does not exist
    if not os.path.exists(DestPath):
        os.makedirs(DestPath)


    # For each image compute the crop image and save it.
    for ImageFile in ImageList:
        print(ImageFile)
        img = cv2.imread(ImageFile,0)
        mask=ComputeMask(img)
        minr, minc, maxr, maxc=ComputeBoxDim(mask)
        CropImg=CropImage(img,minr, minc, maxr, maxc)
        FilePath, FileName = os.path.split(ImageFile) 
        DestFile=DestPath+FileName
        cv2.imwrite(DestFile,CropImg)

print("ok6")
# Out:
# ok6

# %%
# Inputpath and destination path
InputPath='/home/dlinano/AI'
DestPath ='/home/dlinano/AI'+'_Croped/'
ImageList = list(paths.list_images(InputPath))
#print(ImageList)

AutomaticBoxCrop(ImageList,DestPath)

print("okEND")
# Out:
# /home/dlinano/AI/IMG_2302_A0.JPG
# /home/dlinano/AI/IMG_2306_A3.JPG
# /home/dlinano/AI/IMG_2291_A1.JPG
# /home/dlinano/AI/IMG_2295_A0.JPG
# /home/dlinano/AI/IMG_2299_A1.JPG
# /home/dlinano/AI/IMG_2304_A3.JPG
# /home/dlinano/AI/IMG_2316_A3.JPG
# /home/dlinano/AI/IMG_2305_A3.JPG
# /home/dlinano/AI/IMG_2322_A0.JPG
# /home/dlinano/AI/IMG_2306_A0.JPG
# /home/dlinano/AI/IMG_2298_A1.JPG
# /home/dlinano/AI/IMG_2295_A2.JPG
# /home/dlinano/AI/IMG_2305_A0.JPG
# /home/dlinano/AI/IMG_2306_A1.JPG
# /home/dlinano/AI/IMG_2299_A0.JPG
# /home/dlinano/AI/IMG_2322_A1.JPG
# /home/dlinano/AI/IMG_2290_A1.JPG
# /home/dlinano/AI/IMG_2315_A1.JPG
# /home/dlinano/AI/IMG_2297_A0.JPG
# /home/dlinano/AI/IMG_2321_A1.JPG
# /home/dlinano/AI/IMG_2300_A3.JPG
# /home/dlinano/AI/IMG_2291_A3.JPG
# /home/dlinano/AI/IMG_2290_A2.JPG
# /home/dlinano/AI/IMG_2318_A3.JPG
# /home/dlinano/AI/IMG_2305_A2.JPG
# /home/dlinano/AI/IMG_2294_A1.JPG
# /home/dlinano/AI/IMG_2309_A0.JPG
# /home/dlinano/AI/IMG_2296_A2.JPG
# /home/dlinano/AI/IMG_2310_A2.JPG
# /home/dlinano/AI/IMG_2301_A0.JPG
# /home/dlinano/AI/IMG_2290_A3.JPG
# /home/dlinano/AI/IMG_2325_A0.JPG
# /home/dlinano/AI/IMG_2314_A1.JPG
# /home/dlinano/AI/IMG_2321_A0.JPG
# /home/dlinano/AI/IMG_2310_A1.JPG
# /home/dlinano/AI/IMG_2312_A3.JPG
# /home/dlinano/AI/IMG_2292_A1.JPG
# /home/dlinano/AI/IMG_2323_A1.JPG
# /home/dlinano/AI/IMG_2302_A3.JPG
# /home/dlinano/AI/IMG_2301_A3.JPG
# /home/dlinano/AI/IMG_2291_A2.JPG
# /home/dlinano/AI/IMG_2301_A1.JPG
# /home/dlinano/AI/IMG_2303_A3.JPG
# /home/dlinano/AI/IMG_2323_A3.JPG
# /home/dlinano/AI/IMG_2316_A2.JPG
# /home/dlinano/AI/IMG_2316_A0.JPG
# /home/dlinano/AI/IMG_2302_A2.JPG
# /home/dlinano/AI/IMG_2304_A2.JPG
# /home/dlinano/AI/IMG_2309_A2.JPG
# /home/dlinano/AI/IMG_2311_A1.JPG
# /home/dlinano/AI/IMG_2317_A2.JPG
# /home/dlinano/AI/IMG_2320_A2.JPG
# /home/dlinano/AI/IMG_2295_A3.JPG
# /home/dlinano/AI/IMG_2314_A0.JPG
# /home/dlinano/AI/IMG_2311_A2.JPG
# /home/dlinano/AI/IMG_2303_A2.JPG
# /home/dlinano/AI/IMG_2318_A0.JPG
# /home/dlinano/AI/IMG_2308_A1.JPG
# /home/dlinano/AI/IMG_2324_A1.JPG
# /home/dlinano/AI/IMG_2303_A0.JPG
# /home/dlinano/AI/IMG_2317_A0.JPG
# /home/dlinano/AI/IMG_2317_A1.JPG
# /home/dlinano/AI/IMG_2304_A1.JPG
# /home/dlinano/AI/IMG_2310_A3.JPG
# /home/dlinano/AI/IMG_2314_A2.JPG
# /home/dlinano/AI/IMG_2318_A1.JPG
# /home/dlinano/AI/IMG_2302_A1.JPG
# /home/dlinano/AI/IMG_2312_A2.JPG
# /home/dlinano/AI/IMG_2293_A0.JPG
# /home/dlinano/AI/IMG_2307_A3.JPG
# /home/dlinano/AI/IMG_2309_A1.JPG
# /home/dlinano/AI/IMG_2299_A2.JPG
# /home/dlinano/AI/IMG_2296_A1.JPG
# /home/dlinano/AI/IMG_2290_A0.JPG
# /home/dlinano/AI/IMG_2313_A2.JPG
# /home/dlinano/AI/IMG_2300_A2.JPG
# /home/dlinano/AI/IMG_2313_A0.JPG
# /home/dlinano/AI/IMG_2315_A3.JPG
# /home/dlinano/AI/IMG_2322_A2.JPG
# /home/dlinano/AI/IMG_2325_A3.JPG
# /home/dlinano/AI/IMG_2324_A0.JPG
# /home/dlinano/AI/IMG_2307_A0.JPG
# /home/dlinano/AI/IMG_2318_A2.JPG
# /home/dlinano/AI/IMG_2314_A3.JPG
# /home/dlinano/AI/IMG_2320_A1.JPG
# /home/dlinano/AI/IMG_2322_A3.JPG
# /home/dlinano/AI/IMG_2315_A2.JPG
# /home/dlinano/AI/IMG_2299_A3.JPG
# /home/dlinano/AI/IMG_2313_A3.JPG
# /home/dlinano/AI/IMG_2293_A2.JPG
# /home/dlinano/AI/IMG_2319_A1.JPG
# /home/dlinano/AI/IMG_2317_A3.JPG
# /home/dlinano/AI/IMG_2296_A3.JPG
# /home/dlinano/AI/IMG_2319_A3.JPG
# /home/dlinano/AI/IMG_2300_A0.JPG
# /home/dlinano/AI/IMG_2308_A3.JPG
# /home/dlinano/AI/IMG_2294_A0.JPG
# /home/dlinano/AI/IMG_2298_A0.JPG
# /home/dlinano/AI/IMG_2291_A0.JPG
# /home/dlinano/AI/IMG_2301_A2.JPG
# /home/dlinano/AI/IMG_2319_A2.JPG
# /home/dlinano/AI/IMG_2308_A2.JPG
# /home/dlinano/AI/IMG_2296_A0.JPG
# /home/dlinano/AI/IMG_2321_A2.JPG
# /home/dlinano/AI/IMG_2306_A2.JPG
# /home/dlinano/AI/IMG_2323_A0.JPG
# /home/dlinano/AI/IMG_2311_A3.JPG
# /home/dlinano/AI/IMG_2305_A1.JPG
# /home/dlinano/AI/IMG_2308_A0.JPG
# /home/dlinano/AI/IMG_2320_A0.JPG
# /home/dlinano/AI/IMG_2297_A1.JPG
# /home/dlinano/AI/IMG_2295_A1.JPG
# /home/dlinano/AI/IMG_2324_A3.JPG
# /home/dlinano/AI/IMG_2316_A1.JPG
# /home/dlinano/AI/IMG_2293_A1.JPG
# /home/dlinano/AI/IMG_2324_A2.JPG
# /home/dlinano/AI/IMG_2321_A3.JPG
# /home/dlinano/AI/IMG_2325_A2.JPG
# /home/dlinano/AI/IMG_2320_A3.JPG
# /home/dlinano/AI/IMG_2313_A1.JPG
# /home/dlinano/AI/IMG_2297_A3.JPG
# /home/dlinano/AI/IMG_2294_A3.JPG
# /home/dlinano/AI/IMG_2315_A0.JPG
# /home/dlinano/AI/IMG_2312_A0.JPG
# /home/dlinano/AI/IMG_2311_A0.JPG
# /home/dlinano/AI/IMG_2293_A3.JPG
# /home/dlinano/AI/IMG_2297_A2.JPG
# /home/dlinano/AI/IMG_2300_A1.JPG
# /home/dlinano/AI/IMG_2298_A2.JPG
# /home/dlinano/AI/IMG_2292_A2.JPG
# /home/dlinano/AI/IMG_2323_A2.JPG
# /home/dlinano/AI/IMG_2292_A3.JPG
# /home/dlinano/AI/IMG_2310_A0.JPG
# /home/dlinano/AI/IMG_2292_A0.JPG
# /home/dlinano/AI/IMG_2303_A1.JPG
# /home/dlinano/AI/IMG_2307_A2.JPG
# /home/dlinano/AI/IMG_2294_A2.JPG
# /home/dlinano/AI/IMG_2307_A1.JPG
# /home/dlinano/AI/IMG_2325_A1.JPG
# /home/dlinano/AI/IMG_2304_A0.JPG
# /home/dlinano/AI/IMG_2309_A3.JPG
# /home/dlinano/AI/IMG_2319_A0.JPG
# /home/dlinano/AI/IMG_2312_A1.JPG
# /home/dlinano/AI/IMG_2298_A3.JPG
# okEND
